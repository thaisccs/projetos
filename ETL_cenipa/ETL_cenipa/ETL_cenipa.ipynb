# %% [markdown]
# ## INSTALAÇÕES E IMPORTAÇÕES

# %%
pip install -q pandera
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#importação bibliotecas
import pandas as pd
import chardet
import numpy as np
import datetime
import pandera as pa

# %% [markdown]
# ## LENDO O ARQUIVO

# %%
#atribuindo o caminho do arquivo a uma variável
caminho_arquivo = 'C:\\Users\\thais\\Documents\\meusProjetosVersionados\\Primeiro-repositorio\\ETL_cenipa\\ocorrenciass.csv'

# %%
#descobrindo a codificação de texto
with open(caminho_arquivo, 'rb') as f:
    result = chardet.detect(f.read())

# %%
#configurando o máximo de colunas a serem exibidas
pd.set_option('display.max_columns', 100)

# %%
#lendo o arquivo e imprimindo
df = pd.read_csv(caminho_arquivo, sep=';', encoding=result['encoding'], parse_dates=['ocorrencia_dia'], dayfirst=True)

print(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 81027               81027               81027
# 1                 81030               81030               81030
# 2                 81023               81023               81023
# 3                 81029               81029               81029
# 4                 81025               81025               81025
# ...                 ...                 ...                 ...
# 6764              40324               40324               40324
# 6765              39527               39527               39527
# 6766              40211               40211               40211
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  81027               81027          INCIDENTE GRAVE
# 1                  81030               81030                INCIDENTE
# 2                  81023               81023          INCIDENTE GRAVE
# 3                  81029               81029                INCIDENTE
# 4                  81025               81025                INCIDENTE
# ...                  ...                 ...                      ...
# 6764               40324               40324                INCIDENTE
# 6765               39527               39527                 ACIDENTE
# 6766               40211               40211                INCIDENTE
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    NaN                  NaN           SÃO PAULO
# 1                    NaN                  NaN             VITÓRIA
# 2                    NaN                  NaN           AMERICANA
# 3                    NaN                  NaN      BELO HORIZONTE
# 4                    NaN                  NaN              MANAUS
# ...                  ...                  ...                 ...
# 6764                 NaN                  NaN             PELOTAS
# 6765      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 6766                 ***                  ***      RIO DE JANEIRO
# 6767                 NaN                  NaN               BELÉM
# 6768                 NaN                  NaN      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 0               SP          BRASIL                 SBSP     2022-10-09
# 1               ES          BRASIL                 SBVT     2022-10-09
# 2               SP          BRASIL                 SDAI     2022-10-06
# 3               MG          BRASIL                 SBBH     2022-10-06
# 4               AM          BRASIL                 SBEG     2022-10-05
# ...            ...             ...                  ...            ...
# 6764            RS          BRASIL                 SBPK     2010-01-05
# 6765            MT          BRASIL                  ***     2010-01-04
# 6766            RJ          BRASIL                  ***     2010-01-03
# 6767            PA          BRASIL                 SBBE     2010-01-03
# 6768            RJ          BRASIL                 SBRJ     2010-01-03
#
#      ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0           16:30:00                            SIM               ATIVA
# 1           16:20:00                            SIM               ATIVA
# 2           15:30:00                            SIM          FINALIZADA
# 3           00:44:00                            SIM          FINALIZADA
# 4           20:56:00                            SIM          FINALIZADA
# ...              ...                            ...                 ...
# 6764        19:25:00                            SIM          FINALIZADA
# 6765        17:30:00                            SIM          FINALIZADA
# 6766        12:00:00                            SIM          FINALIZADA
# 6767        11:05:00                            SIM          FINALIZADA
# 6768        03:00:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                      A DEFINIR                            NÃO
# 1                      A DEFINIR                            NÃO
# 2                            ***                            NÃO
# 3                            ***                            NÃO
# 4                            ***                            NÃO
# ...                          ...                            ...
# 6764                         NaN                            NÃO
# 6765           A-539/CENIPA/2018                            SIM
# 6766                         ***                            NÃO
# 6767                         NaN                            NÃO
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 0                          NaN                    0
# 1                          NaN                    0
# 2                          NaN                    0
# 3                          NaN                    0
# 4                          NaN                    0
# ...                        ...                  ...
# 6764                       NaN                    0
# 6765                2019-10-28                    0
# 6766                       NaN                    0
# 6767                       NaN                    0
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 0                              1                    SIM
# 1                              1                    NÃO
# 2                              1                    SIM
# 3                              1                    NÃO
# 4                              1                    NÃO
# ...                          ...                    ...
# 6764                           1                    NÃO
# 6765                           1                    NÃO
# 6766                           1                    NÃO
# 6767                           1                    NÃO
# 6768                           1                    NÃO
#
# [6769 rows x 22 columns]

# %% [markdown]
# ## ANÁLISE EXPLORATÓRIA DOS DADOS

# %%
#informações sobre as colunas e seus tipos de dados

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769 entries, 0 to 6768
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   codigo_ocorrencia               6769 non-null   int64
#  1   codigo_ocorrencia1              6769 non-null   int64
#  2   codigo_ocorrencia2              6769 non-null   int64
#  3   codigo_ocorrencia3              6769 non-null   int64
#  4   codigo_ocorrencia4              6769 non-null   int64
#  5   ocorrencia_classificacao        6769 non-null   object
#  6   ocorrencia_latitude             5135 non-null   object
#  7   ocorrencia_longitude            5135 non-null   object
#  8   ocorrencia_cidade               6769 non-null   object
#  9   ocorrencia_uf                   6769 non-null   object
#  10  ocorrencia_pais                 6769 non-null   object
#  11  ocorrencia_aerodromo            6769 non-null   object
#  12  ocorrencia_dia                  6769 non-null   datetime64[ns]
#  13  ocorrencia_hora                 6767 non-null   object
#  14  investigacao_aeronave_liberada  6531 non-null   object
#  15  investigacao_status             6428 non-null   object
#  16  divulgacao_relatorio_numero     5987 non-null   object
#  17  divulgacao_relatorio_publicado  6769 non-null   object
#  18  divulgacao_dia_publicacao       1781 non-null   object
#  19  total_recomendacoes             6769 non-null   int64
#  20  total_aeronaves_envolvidas      6769 non-null   int64
#  21  ocorrencia_saida_pista          6769 non-null   object
# dtypes: datetime64[ns](1), int64(7), object(14)
# memory usage: 1.1+ MB

# %%
#shape do dataframe

df.shape
# Out:
# (6769, 22)

# %%
#lendo as primeiras 5 linhas
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
# 1              81030               81030               81030
# 2              81023               81023               81023
# 3              81029               81029               81029
# 4              81025               81025               81025
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
# 3               81029               81029                INCIDENTE
# 4               81025               81025                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN         SÃO PAULO            SP
# 1                 NaN                  NaN           VITÓRIA            ES
# 2                 NaN                  NaN         AMERICANA            SP
# 3                 NaN                  NaN    BELO HORIZONTE            MG
# 4                 NaN                  NaN            MANAUS            AM
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 SBSP     2022-10-09        16:30:00
# 1          BRASIL                 SBVT     2022-10-09        16:20:00
# 2          BRASIL                 SDAI     2022-10-06        15:30:00
# 3          BRASIL                 SBBH     2022-10-06        00:44:00
# 4          BRASIL                 SBEG     2022-10-05        20:56:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM               ATIVA
# 1                            SIM               ATIVA
# 2                            SIM          FINALIZADA
# 3                            SIM          FINALIZADA
# 4                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                   A DEFINIR                            NÃO
# 1                   A DEFINIR                            NÃO
# 2                         ***                            NÃO
# 3                         ***                            NÃO
# 4                         ***                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
# 2                       NaN                    0                           1
# 3                       NaN                    0                           1
# 4                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    SIM
# 1                    NÃO
# 2                    SIM
# 3                    NÃO
# 4                    NÃO

# %%
#verificando se a coluna codigo_ocorrencia é única para ser considerada como identificador

df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# ## TRATAMENTO DOS DADOS

# %%
#criando backup do data frame

dfback = df.copy()

# %%
#listando os nomes das colunas

df.columns
# Out:
# Index(['codigo_ocorrencia', 'codigo_ocorrencia1', 'codigo_ocorrencia2',
#        'codigo_ocorrencia3', 'codigo_ocorrencia4', 'ocorrencia_classificacao',
#        'ocorrencia_latitude', 'ocorrencia_longitude', 'ocorrencia_cidade',
#        'ocorrencia_uf', 'ocorrencia_pais', 'ocorrencia_aerodromo',
#        'ocorrencia_dia', 'ocorrencia_hora', 'investigacao_aeronave_liberada',
#        'investigacao_status', 'divulgacao_relatorio_numero',
#        'divulgacao_relatorio_publicado', 'divulgacao_dia_publicacao',
#        'total_recomendacoes', 'total_aeronaves_envolvidas',
#        'ocorrencia_saida_pista'],
#       dtype='object')

# %%
#drop colunas desnecessárias para a análise

df.drop(['codigo_ocorrencia2', 'codigo_ocorrencia3',
       'codigo_ocorrencia4', 'ocorrencia_latitude',
       'ocorrencia_longitude','investigacao_aeronave_liberada', 'investigacao_status', 'total_recomendacoes','divulgacao_relatorio_numero', 'divulgacao_relatorio_publicado', 'divulgacao_dia_publicacao'], axis=1, inplace=True)

# %%
#verificando limpeza colunas

df.columns
# Out:
# Index(['codigo_ocorrencia', 'codigo_ocorrencia1', 'ocorrencia_classificacao',
#        'ocorrencia_cidade', 'ocorrencia_uf', 'ocorrencia_pais',
#        'ocorrencia_aerodromo', 'ocorrencia_dia', 'ocorrencia_hora',
#        'total_aeronaves_envolvidas', 'ocorrencia_saida_pista'],
#       dtype='object')

# %%
#renomeando colunas

df.rename(columns={"codigo_ocorrencia1": "codigo_ocorrencia", "ocorrencia_classificacao":"classificacao","ocorrencia_cidade":"cidade","ocorrencia_uf":"uf","ocorrencia_pais":"pais","ocorrencia_aerodromo":"aerodromo","ocorrencia_dia":"data","ocorrencia_hora":"horario","total_aeronaves_envolvidas":"n_aeronaves","ocorrencia_saida_pista":"saida_pista"}, inplace=True)

# %%
#verificando as colunas existentes e seus tipos de dados

df.dtypes
# Out:
# codigo_ocorrencia             int64
# codigo_ocorrencia             int64
# classificacao                object
# cidade                       object
# uf                           object
# pais                         object
# aerodromo                    object
# data                 datetime64[ns]
# horario                      object
# n_aeronaves                   int64
# saida_pista                  object
# dtype: object

# %% [markdown]
# Verificando os valores únicos dentro de cada coluna para localizar possíveis inconsistências

# %%
#verificando os valores únicos dentro das colunas

pd.unique(df['classificacao']) #verifica quais são os valores únicos
sorted(pd.unique(df['classificacao'])) #aqui imprime na tela os valores únicos acima classificados em forma de lista
# Out:
# ['ACIDENTE', 'INCIDENTE', 'INCIDENTE GRAVE']

# %%
#verificando os valores únicos - UF

sorted(pd.unique(df['uf']))
# Out:
# ['***',
#  'AC',
#  'AL',
#  'AM',
#  'AP',
#  'BA',
#  'CE',
#  'DF',
#  'ES',
#  'GO',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'RJ',
#  'RN',
#  'RO',
#  'RR',
#  'RS',
#  'SC',
#  'SE',
#  'SP',
#  'TO']

# %%
#verificando os valores únicos - AERODROMO

sorted(pd.unique(df['aerodromo']))
# Out:
# ['***',
#  '**NI',
#  '5JTI',
#  '9PAA',
#  '9PBS',
#  '9PFC',
#  '9PFX',
#  '9PHD',
#  '9PSD',
#  'APUA',
#  'SBAE',
#  'SBAN',
#  'SBAQ',
#  'SBAR',
#  'SBAT',
#  'SBAU',
#  'SBAX',
#  'SBBE',
#  'SBBH',
#  'SBBI',
#  'SBBP',
#  'SBBQ',
#  'SBBR',
#  'SBBU',
#  'SBBV',
#  'SBBW',
#  'SBBZ',
#  'SBCA',
#  'SBCB',
#  'SBCF',
#  'SBCG',
#  'SBCH',
#  'SBCJ',
#  'SBCP',
#  'SBCR',
#  'SBCT',
#  'SBCX',
#  'SBCY',
#  'SBCZ',
#  'SBDN',
#  'SBEG',
#  'SBEK',
#  'SBFE',
#  'SBFI',
#  'SBFL',
#  'SBFN',
#  'SBFS',
#  'SBFZ',
#  'SBGL',
#  'SBGO',
#  'SBGP',
#  'SBGR',
#  'SBGV',
#  'SBGW',
#  'SBHT',
#  'SBIH',
#  'SBIL',
#  'SBIP',
#  'SBIT',
#  'SBIZ',
#  'SBJA',
#  'SBJC',
#  'SBJD',
#  'SBJF',
#  'SBJH',
#  'SBJI',
#  'SBJP',
#  'SBJR',
#  'SBJU',
#  'SBJV',
#  'SBKG',
#  'SBKP',
#  'SBLE',
#  'SBLJ',
#  'SBLO',
#  'SBMA',
#  'SBMD',
#  'SBME',
#  'SBMG',
#  'SBMK',
#  'SBML',
#  'SBMO',
#  'SBMQ',
#  'SBMS',
#  'SBMT',
#  'SBMY',
#  'SBNF',
#  'SBNM',
#  'SBNT',
#  'SBNV',
#  'SBPA',
#  'SBPB',
#  'SBPC',
#  'SBPF',
#  'SBPG',
#  'SBPJ',
#  'SBPK',
#  'SBPL',
#  'SBPN',
#  'SBPO',
#  'SBPP',
#  'SBPR',
#  'SBPS',
#  'SBPV',
#  'SBQV',
#  'SBRB',
#  'SBRD',
#  'SBRF',
#  'SBRJ',
#  'SBRP',
#  'SBSC',
#  'SBSG',
#  'SBSI',
#  'SBSJ',
#  'SBSL',
#  'SBSM',
#  'SBSN',
#  'SBSP',
#  'SBSR',
#  'SBST',
#  'SBSV',
#  'SBTA',
#  'SBTD',
#  'SBTE',
#  'SBTF',
#  'SBTG',
#  'SBTK',
#  'SBTR',
#  'SBTT',
#  'SBTV',
#  'SBUA',
#  'SBUF',
#  'SBUL',
#  'SBUR',
#  'SBUY',
#  'SBVG',
#  'SBVH',
#  'SBVT',
#  'SBZM',
#  'SD4V',
#  'SD6Y',
#  'SDAA',
#  'SDAE',
#  'SDAG',
#  'SDAI',
#  'SDAM',
#  'SDBA',
#  'SDBB',
#  'SDBK',
#  'SDBN',
#  'SDBV',
#  'SDCD',
#  'SDCO',
#  'SDDN',
#  'SDDQ',
#  'SDDR',
#  'SDED',
#  'SDEE',
#  'SDEH',
#  'SDEM',
#  'SDEN',
#  'SDET',
#  'SDFD',
#  'SDGR',
#  'SDGX',
#  'SDHP',
#  'SDHU',
#  'SDIG',
#  'SDIH',
#  'SDIM',
#  'SDIO',
#  'SDIP',
#  'SDJA',
#  'SDJB',
#  'SDJC',
#  'SDJL',
#  'SDJO',
#  'SDKE',
#  'SDKH',
#  'SDLL',
#  'SDLO',
#  'SDLP',
#  'SDLY',
#  'SDLZ',
#  'SDMC',
#  'SDMH',
#  'SDMJ',
#  'SDMM',
#  'SDMV',
#  'SDNB',
#  'SDNE',
#  'SDNH',
#  'SDNI',
#  'SDOI',
#  'SDOR',
#  'SDOW',
#  'SDPA',
#  'SDPG',
#  'SDPN',
#  'SDPW',
#  'SDPY',
#  'SDQG',
#  'SDRC',
#  'SDRE',
#  'SDRK',
#  'SDRS',
#  'SDRV',
#  'SDSC',
#  'SDTB',
#  'SDTF',
#  'SDTI',
#  'SDTK',
#  'SDTO',
#  'SDUB',
#  'SDUL',
#  'SDVE',
#  'SDVG',
#  'SDVH',
#  'SDVI',
#  'SDVK',
#  'SDVL',
#  'SDVO',
#  'SDWC',
#  'SDWU',
#  'SDWV',
#  'SDXF',
#  'SDYF',
#  'SDYJ',
#  'SDYW',
#  'SDZS',
#  'SDZX',
#  'SIAN',
#  'SIBH',
#  'SIBK',
#  'SIBO',
#  'SIBX',
#  'SIEK',
#  'SIFC',
#  'SIFH',
#  'SIFQ',
#  'SIFV',
#  'SIFW',
#  'SIJG',
#  'SIJY',
#  'SIKC',
#  'SILC',
#  'SILQ',
#  'SILT',
#  'SIMB',
#  'SIMQ',
#  'SING',
#  'SION',
#  'SIPB',
#  'SIPO',
#  'SIPU',
#  'SIPY',
#  'SIQE',
#  'SIQH',
#  'SIQK',
#  'SIRI',
#  'SIRS',
#  'SISN',
#  'SISY',
#  'SIUD',
#  'SIVB',
#  'SIVQ',
#  'SIVU',
#  'SIXD',
#  'SIXE',
#  'SIZM',
#  'SJAH',
#  'SJBH',
#  'SJBM',
#  'SJBX',
#  'SJBY',
#  'SJCY',
#  'SJDU',
#  'SJEH',
#  'SJFM',
#  'SJFU',
#  'SJGL',
#  'SJHG',
#  'SJHR',
#  'SJIF',
#  'SJIJ',
#  'SJLJ',
#  'SJLO',
#  'SJLU',
#  'SJLY',
#  'SJNC',
#  'SJNP',
#  'SJNQ',
#  'SJOD',
#  'SJOG',
#  'SJPT',
#  'SJQN',
#  'SJRG',
#  'SJTO',
#  'SJVL',
#  'SJVO',
#  'SJVX',
#  'SJWQ',
#  'SJXM',
#  'SJYG',
#  'SJYR',
#  'SNAG',
#  'SNAL',
#  'SNAS',
#  'SNAU',
#  'SNAX',
#  'SNAZ',
#  'SNBA',
#  'SNBG',
#  'SNBO',
#  'SNBR',
#  'SNBS',
#  'SNCJ',
#  'SNCL',
#  'SNCP',
#  'SNCT',
#  'SNCV',
#  'SNCW',
#  'SNCX',
#  'SNDC',
#  'SNDH',
#  'SNDP',
#  'SNDR',
#  'SNDT',
#  'SNDU',
#  'SNDV',
#  'SNEJ',
#  'SNEM',
#  'SNFE',
#  'SNFJ',
#  'SNFS',
#  'SNFX',
#  'SNGA',
#  'SNGG',
#  'SNGQ',
#  'SNGS',
#  'SNGU',
#  'SNGV',
#  'SNGW',
#  'SNGX',
#  'SNHB',
#  'SNHE',
#  'SNHH',
#  'SNHS',
#  'SNIG',
#  'SNIT',
#  'SNIZ',
#  'SNJD',
#  'SNJI',
#  'SNJK',
#  'SNJL',
#  'SNJN',
#  'SNJO',
#  'SNJR',
#  'SNKB',
#  'SNKE',
#  'SNKF',
#  'SNKH',
#  'SNKI',
#  'SNKK',
#  'SNLF',
#  'SNLM',
#  'SNLO',
#  'SNMA',
#  'SNMD',
#  'SNME',
#  'SNMH',
#  'SNMU',
#  'SNMX',
#  'SNNL',
#  'SNOD',
#  'SNOF',
#  'SNOG',
#  'SNPA',
#  'SNPC',
#  'SNPD',
#  'SNPJ',
#  'SNPO',
#  'SNPX',
#  'SNPY',
#  'SNQV',
#  'SNQX',
#  'SNRP',
#  'SNRU',
#  'SNSG',
#  'SNSH',
#  'SNSW',
#  'SNTF',
#  'SNTO',
#  'SNTY',
#  'SNUN',
#  'SNUZ',
#  'SNVB',
#  'SNVC',
#  'SNVR',
#  'SNVS',
#  'SNWC',
#  'SNWS',
#  'SNXI',
#  'SNXR',
#  'SNXT',
#  'SNXW',
#  'SNYE',
#  'SNYP',
#  'SNYR',
#  'SNYS',
#  'SNZA',
#  'SSAC',
#  'SSAK',
#  'SSAQ',
#  'SSAU',
#  'SSAY',
#  'SSBG',
#  'SSBL',
#  'SSBN',
#  'SSBR',
#  'SSCD',
#  'SSCE',
#  'SSCF',
#  'SSCK',
#  'SSCL',
#  'SSCN',
#  'SSCP',
#  'SSCR',
#  'SSCT',
#  'SSDK',
#  'SSDO',
#  'SSDP',
#  'SSER',
#  'SSFB',
#  'SSFC',
#  'SSFE',
#  'SSGA',
#  'SSGB',
#  'SSGG',
#  'SSGP',
#  'SSGX',
#  'SSHS',
#  'SSIE',
#  'SSIJ',
#  'SSIQ',
#  'SSJA',
#  'SSJI',
#  'SSJL',
#  'SSKG',
#  'SSKK',
#  'SSKM',
#  'SSKS',
#  'SSKT',
#  'SSKW',
#  'SSKZ',
#  'SSLT',
#  'SSMH',
#  'SSMK',
#  'SSMW',
#  'SSNB',
#  'SSNG',
#  'SSNH',
#  'SSNV',
#  'SSOG',
#  'SSOK',
#  'SSOL',
#  'SSOS',
#  'SSOT',
#  'SSPB',
#  'SSPG',
#  'SSPI',
#  'SSPL',
#  'SSPO',
#  'SSPQ',
#  'SSPS',
#  'SSPV',
#  'SSPX',
#  'SSQI',
#  'SSQT',
#  'SSQZ',
#  'SSRA',
#  'SSRS',
#  'SSRZ',
#  'SSSB',
#  'SSSC',
#  'SSSE',
#  'SSSS',
#  'SSSZ',
#  'SSTH',
#  'SSTL',
#  'SSUB',
#  'SSUL',
#  'SSUV',
#  'SSVA',
#  'SSVN',
#  'SSWF',
#  'SSXO',
#  'SSZL',
#  'SSZR',
#  'SWAQ',
#  'SWBB',
#  'SWBE',
#  'SWCA',
#  'SWCZ',
#  'SWDC',
#  'SWEF',
#  'SWEI',
#  'SWEJ',
#  'SWEK',
#  'SWEN',
#  'SWEW',
#  'SWFN',
#  'SWFR',
#  'SWFV',
#  'SWFX',
#  'SWGC',
#  'SWGI',
#  'SWGL',
#  'SWGN',
#  'SWGP',
#  'SWGW',
#  'SWHP',
#  'SWIN',
#  'SWIT',
#  'SWJN',
#  'SWJP',
#  'SWJW',
#  'SWKC',
#  'SWKO',
#  'SWKT',
#  'SWLB',
#  'SWLC',
#  'SWLV',
#  'SWLW',
#  'SWME',
#  'SWMO',
#  'SWMV',
#  'SWMW',
#  'SWMZ',
#  'SWNB',
#  'SWNG',
#  'SWNH',
#  'SWNK',
#  'SWNO',
#  'SWNS',
#  'SWOB',
#  'SWON',
#  'SWOZ',
#  'SWPA',
#  'SWPD',
#  'SWPI',
#  'SWPM',
#  'SWPQ',
#  'SWPY',
#  'SWQI',
#  'SWRD',
#  'SWRO',
#  'SWRW',
#  'SWRZ',
#  'SWSI',
#  'SWSL',
#  'SWTS',
#  'SWUI',
#  'SWUQ',
#  'SWUV',
#  'SWUZ',
#  'SWVC',
#  'SWVI',
#  'SWVR',
#  'SWVW',
#  'SWVZ',
#  'SWXQ',
#  'SWXV',
#  'SWYH',
#  'SWYV']

# %% [markdown]
# Possíveis inconsistências:
#
# Coluna UF -> "***"
# Coluna AERODROMO -> '***', '**NI'

# %%
#removendo inconsistencias 

'''
As insconsistências serão substituídas por valores nulos, pois é mais indicado trabalhar com valores nulos do que com valores inconsistentes
'''

df.replace(['***', '**NI'], np.NaN, inplace=True)

# %%
#verificando os tipos de dados da coluna

df.dtypes
# Out:
# codigo_ocorrencia             int64
# codigo_ocorrencia             int64
# classificacao                object
# cidade                       object
# uf                           object
# pais                         object
# aerodromo                    object
# data                 datetime64[ns]
# horario                      object
# n_aeronaves                   int64
# saida_pista                  object
# dtype: object

# %% [markdown]
# * Será criado uma nova coluna para a junção de DATA + HORARIO

# %%
#Convertendo a coluna data para str

df['data'] = df['data'].astype(str)

# %%
#criando a nova coluna com a junção das informações e convertendo para o formato datetime 

df['periodo'] = pd.to_datetime(df['data'] + ' ' + df['horario'])

# %%
#confirmando a alteração

df.head(1)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia    classificacao     cidade  uf  \
# 0              81027              81027  INCIDENTE GRAVE  SÃO PAULO  SP
#
#      pais aerodromo        data   horario  n_aeronaves saida_pista  \
# 0  BRASIL      SBSP  2022-10-09  16:30:00            1         SIM
#
#               periodo
# 0 2022-10-09 16:30:00

# %%
#verificando a quantidade de valores nulos

df.isna().sum()
# Out:
# codigo_ocorrencia       0
# codigo_ocorrencia       0
# classificacao           0
# cidade                  0
# uf                      4
# pais                    0
# aerodromo            2618
# data                    0
# horario                 2
# n_aeronaves             0
# saida_pista             0
# periodo                 2
# dtype: int64

# %% [markdown]
# Os valores nulos são em decorrência as substituições das inconsistências.

# %% [markdown]
# ## SCHEMA DE VALIDAÇÃO DOS DADOS

# %%
df.dtypes
# Out:
# codigo_ocorrencia             int64
# codigo_ocorrencia             int64
# classificacao                object
# cidade                       object
# uf                           object
# pais                         object
# aerodromo                    object
# data                         object
# horario                      object
# n_aeronaves                   int64
# saida_pista                  object
# periodo              datetime64[ns]
# dtype: object

# %%
#criando schema de validação com a biblioteca pandera

schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'classificacao' :pa.Column(pa.String),
        'cidade' :pa.Column(pa.String),
        'uf' :pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'pais' :pa.Column(pa.String),
        'aerodromo' :pa.Column(pa.String, pa.Check.str_length(4,4), nullable=True),
        'data' :pa.Column(pa.String),
        'horario':pa.Column(pa.String,pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'), nullable=True),
        'n_aeronaves' :pa.Column(pa.Int),
        'saida_pista' :pa.Column(pa.String, pa.Check.str_length(3,3)),
        'periodo' :pa.Column(pa.DateTime, nullable=True)
    }
    
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia    classificacao  \
# 0                 81027              81027  INCIDENTE GRAVE
# 1                 81030              81030        INCIDENTE
# 2                 81023              81023  INCIDENTE GRAVE
# 3                 81029              81029        INCIDENTE
# 4                 81025              81025        INCIDENTE
# ...                 ...                ...              ...
# 6764              40324              40324        INCIDENTE
# 6765              39527              39527         ACIDENTE
# 6766              40211              40211        INCIDENTE
# 6767              40349              40349        INCIDENTE
# 6768              40351              40351        INCIDENTE
#
#                   cidade  uf    pais aerodromo        data   horario  \
# 0              SÃO PAULO  SP  BRASIL      SBSP  2022-10-09  16:30:00
# 1                VITÓRIA  ES  BRASIL      SBVT  2022-10-09  16:20:00
# 2              AMERICANA  SP  BRASIL      SDAI  2022-10-06  15:30:00
# 3         BELO HORIZONTE  MG  BRASIL      SBBH  2022-10-06  00:44:00
# 4                 MANAUS  AM  BRASIL      SBEG  2022-10-05  20:56:00
# ...                  ...  ..     ...       ...         ...       ...
# 6764             PELOTAS  RS  BRASIL      SBPK  2010-01-05  19:25:00
# 6765  LUCAS DO RIO VERDE  MT  BRASIL       NaN  2010-01-04  17:30:00
# 6766      RIO DE JANEIRO  RJ  BRASIL       NaN  2010-01-03  12:00:00
# 6767               BELÉM  PA  BRASIL      SBBE  2010-01-03  11:05:00
# 6768      RIO DE JANEIRO  RJ  BRASIL      SBRJ  2010-01-03  03:00:00
#
#       n_aeronaves saida_pista             periodo
# 0               1         SIM 2022-10-09 16:30:00
# 1               1         NÃO 2022-10-09 16:20:00
# 2               1         SIM 2022-10-06 15:30:00
# 3               1         NÃO 2022-10-06 00:44:00
# 4               1         NÃO 2022-10-05 20:56:00
# ...           ...         ...                 ...
# 6764            1         NÃO 2010-01-05 19:25:00
# 6765            1         NÃO 2010-01-04 17:30:00
# 6766            1         NÃO 2010-01-03 12:00:00
# 6767            1         NÃO 2010-01-03 11:05:00
# 6768            1         NÃO 2010-01-03 03:00:00
#
# [6769 rows x 12 columns]

# %% [markdown]
# ## FILTROS

# %%
#criando filtros para imprimir quais são os valores nulos da coluna uf

uf_nulo = df.uf.isna()

df.loc[uf_nulo]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia classificacao  \
# 283               80665              80665      ACIDENTE
# 320               80631              80631     INCIDENTE
# 912               79956              79956      ACIDENTE
# 4541              49474              49474      ACIDENTE
#
#                     cidade   uf    pais aerodromo        data   horario  \
# 283       NÃO IDENTIFICADA  NaN  BRASIL       NaN  2022-04-22  20:00:00
# 320       NÃO IDENTIFICADA  NaN  BRASIL       NaN  2022-04-04  11:15:00
# 912       NÃO IDENTIFICADA  NaN  BRASIL       NaN  2021-02-26  11:00:00
# 4541  ÁGUAS INTERNACIONAIS  NaN  BRASIL       NaN  2013-09-02  02:54:00
#
#       n_aeronaves saida_pista             periodo
# 283             1         NÃO 2022-04-22 20:00:00
# 320             1         NÃO 2022-04-04 11:15:00
# 912             1         NÃO 2021-02-26 11:00:00
# 4541            1         NÃO 2013-09-02 02:54:00

# %%
#criando filtro para SP 

sp = df.uf == 'SP'
pista = df.saida_pista == 'SIM'


df_sp = df.loc[sp & pista]

df_sp.head()
# Out:
#      codigo_ocorrencia  codigo_ocorrencia    classificacao           cidade  \
# 0                81027              81027  INCIDENTE GRAVE        SÃO PAULO
# 2                81023              81023  INCIDENTE GRAVE        AMERICANA
# 53               80951              80951  INCIDENTE GRAVE            ASSIS
# 185              80797              80797         ACIDENTE    FERNANDÓPOLIS
# 186              80800              80800         ACIDENTE  RIBEIRÃO BONITO
#
#      uf    pais aerodromo        data   horario  n_aeronaves saida_pista  \
# 0    SP  BRASIL      SBSP  2022-10-09  16:30:00            1         SIM
# 2    SP  BRASIL      SDAI  2022-10-06  15:30:00            1         SIM
# 53   SP  BRASIL      SNAX  2022-08-31  18:45:00            1         SIM
# 185  SP  BRASIL      SDFD  2022-06-17  13:10:00            1         SIM
# 186  SP  BRASIL      SJEH  2022-06-17  17:11:00            1         SIM
#
#                 periodo
# 0   2022-10-09 16:30:00
# 2   2022-10-06 15:30:00
# 53  2022-08-31 18:45:00
# 185 2022-06-17 13:10:00
# 186 2022-06-17 17:11:00

# %% [markdown]
# ## ANÁLISE DOS DADOS

# %%
#groupby para verificar a quantidade de registros por classificação de ocorrência

df.groupby(['classificacao']).size().sort_values(ascending=False)
# Out:
# classificacao
# INCIDENTE          3795
# ACIDENTE           2090
# INCIDENTE GRAVE     884
# dtype: int64

# %%
#Verificando quais são os estados com maior quantidade de ocorrências 

df_uf = df.groupby(['uf']).size().sort_values(ascending=False)

df_uf.head(5)
# Out:
# uf
# SP    1625
# MG     638
# RJ     578
# PR     548
# RS     395
# dtype: int64

# %%
#Listando quais são os estados com maior ocorrência de incidente grave 

df.groupby(['uf', 'classificacao']).size().loc[:, 'INCIDENTE GRAVE'].sort_values(ascending=False)
# Out:
# uf
# SP    163
# GO     86
# MG     86
# PR     71
# RS     58
# MT     55
# RJ     55
# PA     46
# BA     41
# MS     32
# AM     28
# SC     20
# MA     17
# CE     15
# DF     15
# PE     14
# TO     13
# ES     13
# AC     12
# RO      9
# RR      9
# PI      8
# AL      6
# PB      5
# RN      4
# SE      2
# AP      1
# dtype: int64

# %%
#identificando os padrões de ocorrências do estado de São Paulo

df.groupby(['classificacao', 'uf']).size().loc[:, 'SP'].sort_values(ascending=False)
# Out:
# classificacao
# INCIDENTE          1027
# ACIDENTE            435
# INCIDENTE GRAVE     163
# dtype: int64

# %%
#identificando quais são os 10 aerodromos que há maior número de ocorrências

df_aerodromo = df.groupby(['aerodromo']).size().sort_values(ascending=False)

df_aerodromo.head(10)
# Out:
# aerodromo
# SBGR    173
# SBMT    150
# SBKP    128
# SBBH    124
# SBGL    107
# SBBR    104
# SBLO    102
# SBPA     84
# SBEG     82
# SBSP     82
# dtype: int64

# %%
#criando o filtro com o aerodromo específico
aerodromo = df.aerodromo == 'SBGR'

#criando um df somente com os dados do aerodromo do filtro acima 
df_aero_especific = df.loc[aerodromo]

#identificando qual é o padrão de ocorrência do aerodromo analisado
df_aero_especific.groupby(['classificacao']).size().sort_values(ascending=False)
# Out:
# classificacao
# INCIDENTE          164
# INCIDENTE GRAVE      5
# ACIDENTE             4
# dtype: int64

# %%
#criando um filtro para o estado de SP
sp = df.uf == 'SP'

#criando um dataframe só para o estado de SP com o filtro acima 
df_SP = df.loc[sp]

df_SP.groupby(['aerodromo', 'classificacao']).size().sort_values(ascending=False)
# Out:
# aerodromo  classificacao
# SBGR       INCIDENTE        163
# SBKP       INCIDENTE        125
# SBMT       INCIDENTE        122
# SBSP       INCIDENTE         74
# SBJD       INCIDENTE         59
#                            ...
# SDET       INCIDENTE          1
# SDEH       ACIDENTE           1
# SDEE       ACIDENTE           1
# SDED       INCIDENTE          1
# SWYV       ACIDENTE           1
# Length: 176, dtype: int64
